# %% [markdown]
# # Arbitrage ML Model Analysis
# ## Analysis of model performance and feature importance

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
from sklearn.metrics import classification_report, confusion_matrix

# Load model results
# results = pd.read_csv('../models/evaluation_results.csv')

print("🔬 Model Analysis Notebook Ready")
